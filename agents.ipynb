# %%
while true:
    output = llm_call(instructions, messages)
    if output.tools is true:
        tool_output = call_tool(output.tool_name, output.tool_input)
        messages.extend(tool_output)
    else:
        break
